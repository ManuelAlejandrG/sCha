# %% [markdown]
# # Tratando Datos

# %% [markdown]
# ## Importando los Datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('/home/manuelalejandro/Downloads/Master.xlsx' 
)

data.head()
# Out:
#    Unnamed: 0 Unnamed: 1   Unnamed: 2       Unnamed: 3        Unnamed: 4  \
# 0         NaN        NaN          NaN              NaN               NaN
# 1         NaN        NaN          NaN              NaN               NaN
# 2         NaN   Variable           ID  RR Interval (s)  Heart Rate (BPM)
# 3         NaN      Mixed  Scha-cruz 1           0.1386             432.8
# 4         NaN      Mixed  Scha-cruz 2           0.1275             470.6
#
#         Unnamed: 5      Unnamed: 6        Unnamed: 7       Unnamed: 8  \
# 0              NaN             NaN               NaN              NaN
# 1              NaN             NaN               NaN              NaN
# 2  PR Interval (s)  P Duration (s)  QRS Interval (s)  QT Interval (s)
# 3          0.03488          0.0169             0.011          0.08817
# 4          0.04016          0.0235             0.009           0.0825
#
#   Unnamed: 9      Unnamed: 10              Unnamed: 11       Unnamed: 12  \
# ...

# %% [markdown]
# ## Corrigiendo la importación

# %%
data = pd.read_excel('/home/manuelalejandro/Downloads/Master.xlsx', header=3 
)

data.head()
# Out:
#    Unnamed: 0 Variable           ID  RR Interval (s)  Heart Rate (BPM)  \
# 0         NaN    Mixed  Scha-cruz 1           0.1386             432.8
# 1         NaN    Mixed  Scha-cruz 2           0.1275             470.6
# 2         NaN    Mixed  Scha-cruz 3           0.1507             398.3
# 3         NaN     sCha      Scha- 1           0.1608             373.1
# 4         NaN     sCha      Scha- 2           0.1451             413.6
#
#    PR Interval (s)  P Duration (s)  QRS Interval (s)  QT Interval (s)  \
# 0          0.03488         0.01690             0.011          0.08817
# 1          0.04016         0.02350             0.009          0.08250
# 2          0.03982         0.02482             0.011          0.10440
# 3          0.02877         0.01895             0.011          0.06955
# 4          0.03690         0.01996             0.009          0.07670
#
#    QTc (s)  JT Interval (s)  Tpeak Tend Interval (s)  P Amplitude (mV)  \
# ...

# %% [markdown]
# ## Eliminando columna sobrante

# %%
data=data.drop(["Unnamed: 0"], axis=1)
data.head()
# Out:
#   Variable           ID  RR Interval (s)  Heart Rate (BPM)  PR Interval (s)  \
# 0    Mixed  Scha-cruz 1           0.1386             432.8          0.03488
# 1    Mixed  Scha-cruz 2           0.1275             470.6          0.04016
# 2    Mixed  Scha-cruz 3           0.1507             398.3          0.03982
# 3     sCha      Scha- 1           0.1608             373.1          0.02877
# 4     sCha      Scha- 2           0.1451             413.6          0.03690
#
#    P Duration (s)  QRS Interval (s)  QT Interval (s)  QTc (s)  \
# 0         0.01690             0.011          0.08817   0.2368
# 1         0.02350             0.009          0.08250   0.2310
# 2         0.02482             0.011          0.10440   0.2689
# 3         0.01895             0.011          0.06955   0.1734
# 4         0.01996             0.009          0.07670   0.2014
#
#    JT Interval (s)  Tpeak Tend Interval (s)  P Amplitude (mV)  \
# 0          0.07717                  0.07417           0.16980
# ...

# %% [markdown]
# ## Estadística general de los datos

# %%
data.describe()
# Out:
#        RR Interval (s)  Heart Rate (BPM)  PR Interval (s)  P Duration (s)  \
# count        45.000000         45.000000        45.000000       45.000000
# mean          0.138998        455.168889         0.039161        0.017256
# std           0.033861        102.966501         0.006947        0.005176
# min           0.089990        239.100000         0.028770        0.006635
# 25%           0.114900        390.200000         0.034880        0.015710
# 50%           0.136700        439.000000         0.038970        0.018380
# 75%           0.153800        522.100000         0.041360        0.020460
# max           0.251000        666.700000         0.068440        0.026850
#
#        QRS Interval (s)  QT Interval (s)    QTc (s)  JT Interval (s)  \
# count         45.000000        45.000000  45.000000        45.000000
# mean           0.009822         0.083160   0.221740         0.073334
# std            0.001451         0.024664   0.043689         0.024124
# ...

# %%
columns = data.columns.tolist()   # tomar las columnas y volverlas listas
columns
# Out:
# ['Variable',
#  'ID',
#  'RR Interval (s)',
#  'Heart Rate (BPM)',
#  'PR Interval (s)',
#  'P Duration (s)',
#  'QRS Interval (s)',
#  'QT Interval (s)',
#  'QTc (s)',
#  'JT Interval (s)',
#  'Tpeak Tend Interval (s)',
#  'P Amplitude (mV)',
#  'Q Amplitude (mV)',
#  'R Amplitude (mV)',
#  'S Amplitude (mV)',
#  'ST Height (mV)',
#  'T Amplitude (mV)']

# %%
interest_colums=columns[2:]
interest_colums
# Out:
# ['RR Interval (s)',
#  'Heart Rate (BPM)',
#  'PR Interval (s)',
#  'P Duration (s)',
#  'QRS Interval (s)',
#  'QT Interval (s)',
#  'QTc (s)',
#  'JT Interval (s)',
#  'Tpeak Tend Interval (s)',
#  'P Amplitude (mV)',
#  'Q Amplitude (mV)',
#  'R Amplitude (mV)',
#  'S Amplitude (mV)',
#  'ST Height (mV)',
#  'T Amplitude (mV)']

# %% [markdown]
# ## Función especial para el coeficiente de correlación de Pearson entre dos variables de un DataFrame
# ## Recuerde que:
# El valor del índice de correlación varía en el intervalo [-1,1], indicando el signo el sentido de la relación:
#
#     Si r = 1, existe una correlación positiva perfecta. El índice indica una dependencia total entre las dos variables denominada relación directa: cuando una de ellas aumenta, la otra también lo hace en proporción constante.
#     Si 0 < r < 1, existe una correlación positiva.
#     Si r = 0, no existe relación lineal. Pero esto no necesariamente implica que las variables son independientes: pueden existir todavía relaciones no lineales entre las dos variables.
#     Si -1 < r < 0, existe una correlación negativa.
#     Si r = -1, existe una correlación negativa perfecta. El índice indica una dependencia total entre las dos variables llamada relación inversa: cuando una de ellas aumenta, la otra disminuye en proporción constante.

# %%
def corr_coeff(df, var1, var2):
    df["corrn"] = (df[var1] - np.mean(df[var1]))* (df[var2] - np.mean(df[var2]))
    df["corr1"] = (df[var1] - np.mean(df[var1]))**2
    df["corr2"] = (df[var2] - np.mean(df[var2]))**2
    corr_p = sum(df["corrn"])/np.sqrt(sum(df["corr1"]) * sum(df["corr2"]))
    return corr_p

# %% [markdown]
# ## Correlación de la columna RR Interval (s) con las demás.

# %%
for colum in interest_colums:
    print(corr_coeff(data,"RR Interval (s)",colum))
# Out:
# 1.0
# -0.957927309274
# 0.41780594954
# 0.533468328616
# 0.404881421864
# 0.813489986976
# 0.567136641341
# 0.807311514297
# 0.804444055277
# -0.399813723007
# 0.249008120152
# -0.00763730903107
# 0.0128361065146
# -0.0460613379749
# -0.193057754882

# %% [markdown]
# ## Graficaremos las variables que tienen coeficiente de correlación con valor absoluto mayor a 0.85

# %%
plt.scatter(data["RR Interval (s)"], data['Heart Rate (BPM)'])
plt.title("RR Interval (s) vs Heart Rate (BPM)")
plt.xlabel("RR Interval (s)")
plt.ylabel("Heart Rate (BPM)")

# %% [markdown]
# ## Correlación de la columna Heart Rate (BPM) con las demás

# %%
for colum in interest_colums:
    print(corr_coeff(data,"Heart Rate (BPM)",colum))
# Out:
# -0.957927309274
# 1.0
# -0.397193775168
# -0.541660911764
# -0.428102657015
# -0.750395016513
# -0.513559226113
# -0.741380582304
# -0.739785734421
# 0.444887379619
# -0.265160863348
# 0.0483305538952
# -0.0113290272646
# -0.00289159564807
# 0.184010209078

# %% [markdown]
# ## Correlación de la columna PR Interval (s) con las demás

# %%
for colum in interest_colums:
    print(corr_coeff(data,"PR Interval (s)",colum))
# Out:
# 0.41780594954
# -0.397193775168
# 1.0
# 0.354840626366
# 0.234199132276
# 0.47422414212
# 0.41867132662
# 0.470714341653
# 0.430348014132
# -0.144149728612
# 0.135093654587
# -0.0797796509136
# 0.136087769115
# -0.0177928756703
# -0.0994907982839

# %% [markdown]
# ## Correlación de la columna P Duration (s) con las demás

# %%
for colum in interest_colums:
    print(corr_coeff(data,"PR Interval (s)",colum))
# Out:
# 0.41780594954
# -0.397193775168
# 1.0
# 0.354840626366
# 0.234199132276
# 0.47422414212
# 0.41867132662
# 0.470714341653
# 0.430348014132
# -0.144149728612
# 0.135093654587
# -0.0797796509136
# 0.136087769115
# -0.0177928756703
# -0.0994907982839

# %%
##Correlación de la columna P Duration (s) con las demás  QRS Interval (s)',
# 'QT Interval (s)',
# 'QTc (s)',
# 'JT Interval (s)',
# 'Tpeak Tend Interval (s)',
# 'P Amplitude (mV)',
# 'Q Amplitude (mV)',
# 'R Amplitude (mV)',
# 'S Amplitude (mV)',
# 'ST Height (mV)',
# 'T Amplitude (mV)']
# Out:
#   File "<ipython-input-90-27cf53fe6553>", line 2
#     'QT Interval (s)',
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## Correlación de la columna QRS Interval (s)con las demás

# %%
for colum in interest_colums:
    print(corr_coeff(data,"QRS Interval (s)",colum))
# Out:
# 0.404881421864
# -0.428102657015
# 0.234199132276
# 0.283653986418
# 1.0
# 0.396011783757
# 0.323063309925
# 0.344604542237
# 0.337405129245
# -0.0929008382105
# 0.137737548934
# -0.11993714074
# 0.11660409216
# 0.123358329933
# -0.0936375594936

# %% [markdown]
# ## Correlación de la columna QT Interval (s) con las demás

# %%
for colum in interest_colums:
    print(corr_coeff(data,"QT Interval (s)",colum))
# Out:
# 0.813489986976
# -0.750395016513
# 0.47422414212
# 0.504481892828
# 0.396011783757
# 1.0
# 0.937751137965
# 0.998468407383
# 0.995841193634
# -0.215883807897
# 0.187638218936
# 0.125454852749
# -0.094667257139
# 0.104970007519
# -0.00444579695379

# %%
plt.scatter(data["QT Interval (s)"], data['QTc (s)'])
plt.title("QT Interval (s)) vs QTc (s)")
plt.xlabel("QT Interval (s)")
plt.ylabel("QTc (s)")

# %%
plt.scatter(data["QT Interval (s)"], data['JT Interval (s)'])
plt.title("QT Interval (s)) vs JT Interval (s)")
plt.xlabel("QT Interval (s)")
plt.ylabel("JT Interval (s)")
